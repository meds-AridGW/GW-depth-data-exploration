# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import requests
import json
import time

# %%
site_coords = {
 'TWDB.1038101': (34.46, -102.3522),
 'UNLCSD.423037099353801': (42.51028, -99.59429),
 'USGS.340440091231201': (34.07647, -91.3878),
 'USGS.392601112412201': (39.43356, -112.6902),
 'cuyama': (34.89025548, -119.6165171),
 'san_simon_valley': (32.17119, -109.158),
 'mcmullen_valley': (33.95725, -113.08)}

# %%
# Delete later
TWDB_1038101 = ['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01']

UNLCSD_423037099353801 = ['2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01', '2010-12-01', '2011-01-01', '2011-02-01', '2011-03-01', '2011-04-01', '2011-05-01', '2011-06-01', '2011-07-01', '2011-08-01', '2011-09-01', '2011-10-01', '2011-11-01', '2011-12-01', '2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01', '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01', '2013-09-01', '2013-10-01', '2013-11-01', '2013-12-01', '2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01']

USGS_340440091231201 = ['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01']

USGS_392601112412201 = ['2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01', '2010-12-01', '2011-01-01', '2011-02-01', '2011-03-01', '2011-04-01', '2011-05-01', '2011-06-01', '2011-07-01', '2011-08-01', '2011-09-01', '2011-10-01', '2011-11-01', '2011-12-01', '2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01', '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01', '2013-09-01', '2013-10-01', '2013-11-01', '2013-12-01', '2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01']

cuyama = ['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01', '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01', '2000-09-01', '2000-10-01', '2000-11-01', '2000-12-01', '2001-01-01', '2001-02-01', '2001-03-01', '2001-04-01', '2001-05-01', '2001-06-01', '2001-07-01', '2001-08-01', '2001-09-01', '2001-10-01', '2001-11-01', '2001-12-01', '2002-01-01', '2002-02-01', '2002-03-01', '2002-04-01', '2002-05-01', '2002-06-01', '2002-07-01', '2002-08-01', '2002-09-01', '2002-10-01', '2002-11-01', '2002-12-01', '2003-01-01', '2003-02-01', '2003-03-01', '2003-04-01', '2003-05-01', '2003-06-01', '2003-07-01', '2003-08-01', '2003-09-01', '2003-10-01', '2003-11-01', '2003-12-01', '2004-01-01', '2004-02-01', '2004-03-01', '2004-04-01', '2004-05-01', '2004-06-01', '2004-07-01', '2004-08-01', '2004-09-01', '2004-10-01', '2004-11-01', '2004-12-01', '2005-01-01', '2005-02-01', '2005-03-01', '2005-04-01', '2005-05-01', '2005-06-01', '2005-07-01', '2005-08-01', '2005-09-01', '2005-10-01', '2005-11-01', '2005-12-01', '2006-01-01', '2006-02-01', '2006-03-01', '2006-04-01', '2006-05-01', '2006-06-01', '2006-07-01', '2006-08-01', '2006-09-01', '2006-10-01', '2006-11-01', '2006-12-01', '2007-01-01', '2007-02-01', '2007-03-01', '2007-04-01', '2007-05-01', '2007-06-01', '2007-07-01', '2007-08-01', '2007-09-01', '2007-10-01', '2007-11-01', '2007-12-01', '2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01', '2008-05-01', '2008-06-01', '2008-07-01', '2008-08-01', '2008-09-01', '2008-10-01', '2008-11-01', '2008-12-01', '2009-01-01', '2009-02-01', '2009-03-01', '2009-04-01', '2009-05-01', '2009-06-01', '2009-07-01', '2009-08-01', '2009-09-01', '2009-10-01', '2009-11-01', '2009-12-01']

san_simon_valley = ['2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01', '2010-12-01', '2011-01-01', '2011-02-01', '2011-03-01', '2011-04-01', '2011-05-01', '2011-06-01', '2011-07-01', '2011-08-01', '2011-09-01', '2011-10-01', '2011-11-01', '2011-12-01', '2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01', '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01', '2013-09-01', '2013-10-01', '2013-11-01', '2013-12-01', '2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01']

mcmullen_valley = ['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01']

# %%
for tup in site_names.items():
         max_date = max(tup[1])
         min_date = min(tup[1])
         print(tup[0], min_date, max_date)
# Out:
# TWDB_1038101 2020-01-01 2024-12-01
# UNLCSD_423037099353801 2010-01-01 2019-12-01
# USGS_340440091231201 2020-01-01 2024-12-01
# USGS_392601112412201 2010-01-01 2019-12-01
# cuyama 2000-01-01 2009-12-01
# san_simon_valley 2010-01-01 2019-12-01
# mcmullen_valley 2020-01-01 2024-12-01

# %%
header = {"Authorization": "IeZA48KSBbWoU3a50ybYlaA77Qeal3H2UKLAA86KYJ9UKw94rXmcHKhxEOTg"}

size_km = 2

site_date_ranges = {
    'cuyama':                   [("2000-01-01", "2009-12-31", 2.0)], 
    'san_simon_valley':         [("2010-01-01", "2019-12-31", 2.0)], 
    'mcmullen_valley':          [("2020-01-01", "2024-12-31", 2.1)], 
    'TWDB.1038101':             [("2020-01-01", "2024-12-31", 2.1)], 
    'UNLCSD.423037099353801':   [("2010-01-01", "2019-12-31", 2.0)], 
    'USGS.340440091231201':     [("2020-01-01", "2024-12-31", 2.1)], 
    'USGS.392601112412201':     [("2010-01-01", "2019-12-31", 2.0)], 
}

dfs = []

# Create function to generate boundary box given coordinates and boundary box size
def make_square_geometry(lat, lon, size_km):
    half = size_km / 2
    lat_offset = half / 111.0
    lon_offset = half / (111.0 * np.cos(np.radians(lat)))
    return [
        lon - lon_offset, lat + lat_offset,
        lon - lon_offset, lat - lat_offset,
        lon + lon_offset, lat - lat_offset,
        lon + lon_offset, lat + lat_offset,
        lon - lon_offset, lat + lat_offset,
    ]

# Retry failed requests to handle intermittent server errors
def query_with_retry(header, polygon_args, retries=3, wait=5):
    for attempt in range(retries):
        resp = requests.post(
            headers=header,
            json=polygon_args,
            url="https://openet-api.org/raster/timeseries/polygon"
        )
        if resp.status_code == 200:
            return resp
        print(f"    Attempt {attempt + 1} failed — retrying in {wait}s...")
        time.sleep(wait)
    return resp

for name, (lat, lon) in site_coords.items():
    print(f"Querying {name}...")
    
    for start_date, end_date, version in site_date_ranges[name]:  # use per-site ranges

        polygon_args = {
            "date_range": [start_date, end_date],
            "interval": "monthly",
            "geometry": make_square_geometry(lat, lon, size_km),
            "model": "Ensemble",
            "reducer": "mean",
            "variable": "ET",
            "reference_et": "gridMET",
            "units": "mm",
            "file_format": "JSON",
            "version": version
        }

        resp = query_with_retry(header, polygon_args)
        print(f"  {name} {start_date}–{end_date} v{version} — Status: {resp.status_code}")

        if resp.status_code != 200:
            print(f"  ERROR: {resp.json()}")
            continue

        data = resp.json()
        df = pd.DataFrame(data)
        df["site"] = name
        df["latitude"] = lat
        df["longitude"] = lon
        df["bbox_side"] = size_km
        df["open_et_version"] = version
        dfs.append(df)

df_missing = pd.concat(dfs, ignore_index=True)
df_missing.to_csv("et_missing_fills_2.csv", index=False)
print(f"Saved {len(df_missing)} rows")
# Out:
# Querying TWDB.1038101...
#   TWDB.1038101 2000-01-01–2009-12-31 v2.0 — Status: 200
# Querying UNLCSD.423037099353801...
#   UNLCSD.423037099353801 2000-01-01–2009-12-31 v2.0 — Status: 200
# Querying USGS.340440091231201...
#   USGS.340440091231201 2000-01-01–2009-12-31 v2.0 — Status: 200
# Querying USGS.392601112412201...
#   USGS.392601112412201 2000-01-01–2009-12-31 v2.0 — Status: 200
# Querying cuyama...
#   cuyama 2010-01-01–2019-12-31 v2.0 — Status: 200
# Querying san_simon_valley...
#   san_simon_valley 2000-01-01–2009-12-31 v2.0 — Status: 200
# Querying mcmullen_valley...
#   mcmullen_valley 2000-01-01–2009-12-31 v2.0 — Status: 200
# Saved 840 rows

# %%
header = {"Authorization": "IeZA48KSBbWoU3a50ybYlaA77Qeal3H2UKLAA86KYJ9UKw94rXmcHKhxEOTg"}

# %%
size_km = 2

date_ranges = [
    ("2020-01-01", "2024-12-31", 2.1),
]

def make_square_geometry(lat, lon, size_km):
    half = size_km / 2
    lat_offset = half / 111.0
    lon_offset = half / (111.0 * np.cos(np.radians(lat)))
    return [
        lon - lon_offset, lat + lat_offset,
        lon - lon_offset, lat - lat_offset,
        lon + lon_offset, lat - lat_offset,
        lon + lon_offset, lat + lat_offset,
        lon - lon_offset, lat + lat_offset,
    ]

def query_with_retry(header, polygon_args, retries=3, wait=5):
    for attempt in range(retries):
        resp = requests.post(
            headers=header,
            json=polygon_args,
            url="https://openet-api.org/raster/timeseries/polygon"
        )
        if resp.status_code == 200:
            return resp
        print(f"    Attempt {attempt + 1} failed (status {resp.status_code}) — retrying in {wait}s...")
        time.sleep(wait)
    return resp

dfs = []

for name, (lat, lon) in site_coords.items():
    print(f"Querying {name}...")
    
    for start_date, end_date, version in date_ranges:

        polygon_args = {
            "date_range": [start_date, end_date],
            "interval": "monthly",
            "geometry": make_square_geometry(lat, lon, size_km),
            "model": "Ensemble",
            "reducer": "mean",
            "variable": "ET",
            "reference_et": "gridMET",
            "units": "mm",
            "file_format": "JSON",
            "version": version
        }

        resp = query_with_retry(header, polygon_args)

        print(f"  {name} {start_date}–{end_date} — Status: {resp.status_code}")

        if resp.status_code != 200:
            print(f"  ERROR: {resp.json()}")
            continue

        data = resp.json()
        df = pd.DataFrame(data)
        df["site"] = name
        df["latitude"] = lat
        df["longitude"] = lon
        df["bbox_side"] = size_km
        df["open_et_version"] = version
        dfs.append(df)

df_monthly = pd.concat(dfs, ignore_index=True)
print(df_monthly.head())
df_monthly.to_csv("et_2020_2024.csv", index=False)
print("Saved to et_2020_2024.csv")
# Out:
# Querying KSGS.371852100505801...
#   KSGS.371852100505801 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.372043101363101...
#   KSGS.372043101363101 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.372539100142504...
#   KSGS.372539100142504 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.373331098033301...
#   KSGS.373331098033301 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.373607100565301...
#   KSGS.373607100565301 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.374111099070401...
#   KSGS.374111099070401 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.374125100344101...
#   KSGS.374125100344101 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.374747100552101...
#   KSGS.374747100552101 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.375145100485701...
#   KSGS.375145100485701 2025-01-01–2025-12-31 — Status: 200
# Querying KSGS.375454101075401...
#   KSGS.375454101075401 2025-01-01–2025-12-31 — Status: 200
# Querying TWDB.0753701...
# ...

# %%
# Before the loop, print one test request
test_lat, test_lon = list(site_coords.values())[0]
test_args = {
    "date_range": ["2020-01-01", "2024-12-31"],
    "interval": "monthly",
    "geometry": make_square_geometry(test_lat, test_lon, size_km),
    "model": "Ensemble",
    "reducer": "mean",
    "variable": "ET",
    "reference_et": "gridMET",
    "units": "mm",
    "file_format": "JSON",
    "version": 2.0  # try 2.0 first
}
print(json.dumps(test_args, indent=2))
resp = requests.post(headers=header, json=test_args, url="https://openet-api.org/raster/timeseries/polygon")
print(resp.status_code, resp.json())
# Out:
# {
#   "date_range": [
#     "2020-01-01",
#     "2024-12-31"
#   ],
#   "interval": "monthly",
#   "geometry": [
#     -100.86182760428409,
#     37.324029009009,
#     -100.86182760428409,
#     37.30601099099099,
#     -100.8391723957159,
#     37.30601099099099,
#     -100.8391723957159,
#     37.324029009009,
#     -100.86182760428409,
#     37.324029009009
#   ],
#   "model": "Ensemble",
#   "reducer": "mean",
#   "variable": "ET",
#   "reference_et": "gridMET",
#   "units": "mm",
#   "file_format": "JSON",
#   "version": 2.0
# }
# 404 {'detail': 'Invalid geometry, cannot be parsed. Please check formatting.'}
